# %%
pip install -q --upgrade huggingface_hub
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.0/618.0 kB 12.4 MB/s eta 0:00:00

# %%
# !hf auth login
# Out:
# User is already logged in. Use `hf auth login --force` to force re-login.

# %%
from huggingface_hub import HfApi

model_names = [
    "GemMaroc/GemMaroc-4b-deita",
    "GemMaroc/GemMaroc-27b-it",
    "AbderrahmanSkiredj1/GemMaroc-27b-it",
    "GemMaroc/GemMaroc-4b-tulu",
    "mradermacher/GemMaroc-27b-it-GGUF",
    "AbderrahmanSkiredj1/GemMaroc-4b-tulu-Q4_K_M-GGUF",
    "AbderrahmanSkiredj1/GemMaroc-27b-it-GGUF",
    "mradermacher/GemMaroc-4b-tulu-GGUF",
    "mradermacher/GemMaroc-4b-tulu-i1-GGUF",
    "AbderrahmanSkiredj1/GemMaroc-4b-v1.5",
    "AbderrahmanSkiredj1/GemMaroc-4b-v1.5-Q4_K_M-GGUF",
    "GemMaroc/Qwen2.5-7B-Instruct-darija",
    "GemMaroc/Qwen2.5-14B-Instruct-darija",
    "GemMaroc/Qwen2.5-32B-Instruct-darija",
    "MathematicianNLPer/GemMaroc-4b-tulu-Q4_K_M-GGUF",
    "MathematicianNLPer/GemMaroc-27b-it-GGUF",
    "MathematicianNLPer/GemMaroc-27b-it",
    "MathematicianNLPer/GemMaroc-4b-tulu",
    "MathematicianNLPer/GemMaroc-4b-deita",
    "GemMaroc/Qwen2.5-14B-Instruct-dari",
    "GemMaroc/Qwen2.5-7B-Instruct-darija-gguf",
    "GemMaroc/Qwen2.5-14B-Instruct-darija-gguf",
    "GemMaroc/Qwen2.5-32B-Instruct-darija-gguf",
    "yibba/GemMaroc-Qwen2.5-7B-Instruct-Therapy-Darija",
    "GemMaroc/Gemma-3-27b-it-atlaschat-50k-data",
    "GemMaroc/Gemma-3-27b-it-atlaschat-50k-data-plus-tulu",
]
all_downloads = 0
for model_name in model_names:
    api = HfApi()
    info = api.model_info(
        repo_id=model_name,
        expand="downloadsAllTime"
    )
    all_downloads += info.downloads_all_time
all_downloads
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# 26505

# %%
print(all_downloads)
# Out:
# 26505
